# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\konka\\Desktop\\BlackFriday.csv")

# %%
df=data

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %% [markdown]
# ### Gender and Age coloum

# %%
grouped = df.groupby(['Age', 'Gender'])["Gender"].count().reset_index(name="Count")

# %%
grouped
# Out:
#       Age Gender   Count
# 0    0-17      F    4953
# 1    0-17      M    9754
# 2   18-25      F   24057
# 3   18-25      M   73577
# 4   26-35      F   49348
# 5   26-35      M  165342
# 6   36-45      F   26420
# 7   36-45      M   81079
# 8   46-50      F   12856
# 9   46-50      M   31670
# 10  51-55      F    9634
# 11  51-55      M   27984
# 12    55+      F    4929
# 13    55+      M   15974

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=grouped, x="Age", y="Count", hue="Gender")
plt.title("Gender Count by Age Group")
plt.show()

# %%
sns.countplot(data=df,x="Gender",hue="Age")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x="Gender",hue="Marital_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x="Age",hue="Marital_Status")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x="Occupation")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df,x="City_Category")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=df,x="Age",hue="City_Category")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby("City_Category").size()
# Out:
# City_Category
# A    144638
# B    226493
# C    166446
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df,hue="City_Category",x="Occupation")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df,hue="Marital_Status",x="City_Category")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
df.groupby("Marital_Status")["Purchase"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Marital_Status'>

# %% [markdown]
# # occupational and product analysis

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# 4     70862
# 0     68120
# 7     57806
# 1     45971
# 17    39090
# 20    32910
# 12    30423
# 14    26712
# 2     25845
# 16    24790
# 6     19822
# 3     17366
# 10    12623
# 5     11985
# 15    11812
# 11    11338
# 19     8352
# 13     7548
# 18     6525
# 9      6153
# 8      1524
# Name: count, dtype: int64

# %%
df["Occupation"].value_counts().plot(kind="pie", autopct="%.1f%%", figsize=(8, 8))
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x="Occupation")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x="Occupation",hue="Marital_Status")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x="Occupation",hue="Gender")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x="Occupation",hue="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df,x="City_Category",hue="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("Occupation")["Purchase"].count().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Purchase"].sum().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Purchase"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370

# %%
sns.countplot(data=df,x="Product_Category_1")
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
df.groupby("Product_Category_1")["Purchase"].count().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1")["Purchase"].sum().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_ID")["Purchase"].sum().nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID")["Purchase"].count().nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # WHich Gender is more married or unmarried

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
sns.countplot(data=df,x="Gender",hue="Marital_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# # Which female or male are more married or nmarried are more

# %%
l=[]
for i in range(len(df)):
    l.append(df["Gender"][i]+"_"+str(df["Marital_Status"][i]))
df["Marital_Status_checkindividually"]=l

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
#
#   Marital_Status_checkindividually
# 0                              F_0
# 1                              F_0

# %%
sns.countplot(data=df,x="Marital_Status_checkindividually")
# Out:
# <Axes: xlabel='Marital_Status_checkindividually', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x="Occupation",hue="Marital_Status_checkindividually")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>
